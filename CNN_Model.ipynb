# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 50
CHANNELS = 3
EPOCHS = 30

# %%
import os

List = os.listdir(".\\dataset\\valid")
number_files = 0
for p in List:
    number_files += len(os.listdir(".\\dataset\\valid\\" + p))
print(number_files)
# Out:
# 17572

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    ".\\dataset\\valid",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
class_names = dataset.class_names
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
train_dataset = dataset.take(300)
valid_dataset = dataset.skip(300)

test_dataset = valid_dataset.take(25)
valid_dataset = valid_dataset.skip(25)

# %%
len(test_dataset)
# Out:
# 25

# %%
for image_batch, label_batch in train_dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (50, 256, 256, 3)
# [21  4  6 10 29 35 28 11  2 15 22 22 26  3 14 25 12  6 15 37 36 13 25 30
#   1 28 20 18 36 26 37  8 24 37 34 15 16 23 28  9 35 37 12 19 21 23 24  6
#   7  7]

# %%
plt.figure(figsize = (15, 15))
for image_batch, label_batch in train_dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
train_dataset = train_dataset.cache().shuffle(200).prefetch(buffer_size=tf.data.AUTOTUNE)
valid_dataset = valid_dataset.cache().shuffle(200).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = test_dataset.cache().shuffle(200).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
n_classes = 38
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(50, kernel_size = (3, 3), activation = 'relu', input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(n_classes, activation = 'softmax')
])

# %%
model.build(input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (50, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (50, 254, 254, 50)        1400
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (50, 127, 127, 50)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (50, 125, 125, 32)        14432
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (50, 62, 62, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (50, 60, 60, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (50, 30, 30, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (50, 28, 28, 32)          9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (50, 14, 14, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (50, 12, 12, 32)          9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (50, 6, 6, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (50, 1152)                0
# _________________________________________________________________
# dense (Dense)                (50, 64)                  73792
# _________________________________________________________________
# dense_1 (Dense)              (50, 38)                  2470
# =================================================================
# Total params: 119,838
# Trainable params: 119,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
len(test_dataset)
# Out:
# 25

# %%
history = model.fit(
    train_dataset,
    epochs =  EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = valid_dataset
)
# Out:
# Epoch 1/30
# 300/300 [==============================] - 991s 3s/step - loss: 2.8356 - accuracy: 0.2210 - val_loss: 1.8953 - val_accuracy: 0.4380
# Epoch 2/30
# 300/300 [==============================] - 863s 3s/step - loss: 1.5471 - accuracy: 0.5422 - val_loss: 1.3425 - val_accuracy: 0.5930
# Epoch 3/30
# 300/300 [==============================] - 828s 3s/step - loss: 1.1213 - accuracy: 0.6552 - val_loss: 1.0818 - val_accuracy: 0.6740
# Epoch 4/30
# 300/300 [==============================] - 819s 3s/step - loss: 0.8803 - accuracy: 0.7257 - val_loss: 0.8495 - val_accuracy: 0.7307
# Epoch 5/30
# 300/300 [==============================] - 986s 3s/step - loss: 0.7309 - accuracy: 0.7681 - val_loss: 0.9735 - val_accuracy: 0.6740
# Epoch 6/30
# 300/300 [==============================] - 813s 3s/step - loss: 0.6009 - accuracy: 0.8082 - val_loss: 0.6991 - val_accuracy: 0.7791
# Epoch 7/30
# 300/300 [==============================] - 1332s 4s/step - loss: 0.5071 - accuracy: 0.8413 - val_loss: 0.6088 - val_accuracy: 0.8011
# Epoch 8/30
# 300/300 [==============================] - 980s 3s/step - loss: 0.4347 - accuracy: 0.8596 - val_loss: 0.7568 - val_accuracy: 0.7519
# Epoch 9/30
# 300/300 [==============================] - 904s 3s/step - loss: 0.3774 - accuracy: 0.8772 - val_loss: 0.5815 - val_accuracy: 0.8260
# Epoch 10/30
# 300/300 [==============================] - 858s 3s/step - loss: 0.3210 - accuracy: 0.8941 - val_loss: 0.8551 - val_accuracy: 0.7390
# Epoch 11/30
# 300/300 [==============================] - 1125s 4s/step - loss: 0.2818 - accuracy: 0.9051 - val_loss: 0.6003 - val_accuracy: 0.8245
# Epoch 12/30
# 300/300 [==============================] - 864s 3s/step - loss: 0.2376 - accuracy: 0.9215 - val_loss: 0.5958 - val_accuracy: 0.8079
# Epoch 13/30
# 300/300 [==============================] - 903s 3s/step - loss: 0.2172 - accuracy: 0.9243 - val_loss: 0.7275 - val_accuracy: 0.8177
# Epoch 14/30
# 300/300 [==============================] - 998s 3s/step - loss: 0.1750 - accuracy: 0.9409 - val_loss: 0.6825 - val_accuracy: 0.8222
# Epoch 15/30
# 300/300 [==============================] - 915s 3s/step - loss: 0.1700 - accuracy: 0.9403 - val_loss: 0.6486 - val_accuracy: 0.8434
# Epoch 16/30
# 300/300 [==============================] - 868s 3s/step - loss: 0.1581 - accuracy: 0.9457 - val_loss: 0.6703 - val_accuracy: 0.8306
# Epoch 17/30
# 300/300 [==============================] - 817s 3s/step - loss: 0.1395 - accuracy: 0.9521 - val_loss: 0.7065 - val_accuracy: 0.8328
# Epoch 18/30
# 300/300 [==============================] - 798s 3s/step - loss: 0.1322 - accuracy: 0.9550 - val_loss: 0.7401 - val_accuracy: 0.8079
# Epoch 19/30
# 300/300 [==============================] - 909s 3s/step - loss: 0.1067 - accuracy: 0.9619 - val_loss: 0.7077 - val_accuracy: 0.8464
# Epoch 20/30
# 300/300 [==============================] - 828s 3s/step - loss: 0.1136 - accuracy: 0.9617 - val_loss: 0.8093 - val_accuracy: 0.8169
# Epoch 21/30
# 300/300 [==============================] - 906s 3s/step - loss: 0.0999 - accuracy: 0.9662 - val_loss: 0.8822 - val_accuracy: 0.8215
# Epoch 22/30
# 300/300 [==============================] - 986s 3s/step - loss: 0.0958 - accuracy: 0.9656 - val_loss: 0.7099 - val_accuracy: 0.8411
# Epoch 23/30
# 300/300 [==============================] - 972s 3s/step - loss: 0.0922 - accuracy: 0.9695 - val_loss: 0.9447 - val_accuracy: 0.8101
# Epoch 24/30
# 300/300 [==============================] - 898s 3s/step - loss: 0.1064 - accuracy: 0.9639 - val_loss: 0.7725 - val_accuracy: 0.8457
# Epoch 25/30
# 300/300 [==============================] - 854s 3s/step - loss: 0.0796 - accuracy: 0.9749 - val_loss: 0.7037 - val_accuracy: 0.8495
# Epoch 26/30
# 300/300 [==============================] - 1213s 4s/step - loss: 0.0794 - accuracy: 0.9746 - val_loss: 0.7483 - val_accuracy: 0.8427
# Epoch 27/30
# 300/300 [==============================] - 842s 3s/step - loss: 0.0811 - accuracy: 0.9729 - val_loss: 0.7544 - val_accuracy: 0.8404
# Epoch 28/30
# 300/300 [==============================] - 880s 3s/step - loss: 0.0813 - accuracy: 0.9721 - val_loss: 0.6967 - val_accuracy: 0.8449
# Epoch 29/30
# 300/300 [==============================] - 909s 3s/step - loss: 0.0513 - accuracy: 0.9827 - val_loss: 0.8563 - val_accuracy: 0.8321
# Epoch 30/30
# 300/300 [==============================] - 839s 3s/step - loss: 0.0822 - accuracy: 0.9720 - val_loss: 1.2329 - val_accuracy: 0.7852

# %%
scores = model.evaluate(test_dataset)
# Out:
# 25/25 [==============================] - 25s 502ms/step - loss: 0.8594 - accuracy: 0.8328

# %%
scores
# Out:
# [0.8594110608100891, 0.8327999711036682]

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label = 'Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label = 'Training Loss')
plt.plot(range(EPOCHS), val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#model.save(f"../models/cnn_model2")

# %%
import numpy as np
for images_batch, labels_batch in test_dataset.take(1):
    first_image = (images_batch[0].numpy().astype('uint8'))
    first_label = labels_batch[0]
    print("first image to predict")
    plt.imshow(first_image)
    print("first image's actual label: ", class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label: ", class_names[np.argmax(batch_prediction[0])])
    if(class_names[first_label] == class_names[np.argmax(batch_prediction[0])]):
        print("Right Prediction")
# Out:
# first image to predict
# first image's actual label:  Peach___Bacterial_spot
# predicted label:  Peach___Bacterial_spot
# Right Prediction

# %%
new_model = tf.keras.models.load_model('../models/cnn_model(sumit)')

# %%
#import numpy as np
#for images_batch, labels_batch in test_dataset.take(1):
#    first_image = (images_batch[0].numpy().astype('uint8'))
#    first_label = labels_batch[0]
#    print("first image to predict")
#    plt.imshow(first_image)
#    print("first image's actual label: ", class_names[first_label])
#    
#    batch_prediction = new_model.predict(images_batch)
#    print("predicted label: ", class_names[np.argmax(batch_prediction[0])])
#    if(class_names[first_label] == class_names[np.argmax(batch_prediction[0])]):
#        print("Right Prediction")

# %%
scores = new_model.evaluate(test_dataset)
# Out:
# 25/25 [==============================] - 12s 488ms/step - loss: 0.3203 - accuracy: 0.9168

# %%
print("Accuracy: ", scores[1])
# Out:
# Accuracy:  0.9175999760627747
